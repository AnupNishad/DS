# %%
#Soultion 1
'''
    Empty dictionary looks like d = {}
'''

# %%
#Soultion 2
'''
    d = {"foo":42}
    Key = 'foo'
    Value = 42
'''

# %%
#Soultion 3
'''
    List - 
            1. The items stored in a dictionary are unordered.
            2. The elements are accessed via indices.
            3. List is created by placing elements in [] separated by commas ",".
            
    Dictionary - 
            1. The items stored in a dictionary are unordered.
            2. The elements are accessed via key-values.
            3. Dictionary is created by placing elements in { } as "key":"value", each key value pair is separated by commas ",".
'''

# %%
#Soultion 4
'''
    We will get KeyError.
'''

# %%
#Soultion 5
'''
    There is no difference.If we have dictionary as spam = {'cat': 100}, both expression will provide True as output.
    1. 'cat' in spam - True
    2. 'cat' in spam.keys() - True
    
'''

# %%
#Soultion 6
'''
    If we have dictionary as spam = {'cat': 100},will get following output : 
    
    1. 'cat' in spam - True (Checks whether there is a 'cat' key in the dictionary)
    2. 'cat' in spam.values() - False (Checks whether there is a value 'cat' for one of the keys in spam)
    
'''

# %%
#Soultion 7
'''
    if 'color' not in spam:
    spam['color'] = 'black'
    
    For above code shortcut code is as below :
    
    spam.setdefault('color', 'black')
    
'''

# %%
#Soultion 8
'''
    We can "pretty print" dictionary values using below module and function :
    
    pprint.pprint()
    
'''
