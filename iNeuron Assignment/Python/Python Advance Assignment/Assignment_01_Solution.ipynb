# %%
#Solution 1
'''
    Object-oriented Programming (OOPs) is a programming paradigm that uses objects and classes in programming.
       
    1. Helps in easy maintenance and modification of existing program.
    2. The main concept of OOPs is to bind the data and the functions that work on that together as a single unit so that no other part of the code can access this data.
    3. It helps to divide our over all program into different small segments and thus making it solving easy with the use of objects
    4. It aims to implement real-world entities like inheritance, polymorphisms, encapsulation, etc. in the programming.
'''

# %%
#Solution 2
'''
    Inheritance search is simply a search of the tree from bottom to top looking for the lowest occurrence of an attribute name.
    Python ensures that subclasses come before superclasses and classes earlier in a list of base classes come before classes later in a list of base classes.
'''

# %%
#Solution 3
'''
   1. Class Object    - 
                       1. A class is a template for creating objects in program.
                       2. A class is a logical entity.
                       3. A class does not allocate memory space when it is created.
                       4. We can declare class only once.
                       5. Classes can’t be manipulated
                       
   2. Instance object -
                       1. The object is an instance of a class
                       2. Object is a physical entity
                       3. Object allocates memory space whenever they are created.
                       4. We can create more than one object using a class.
                       5. Objects can be manipulated
'''

# %%
#Solution 4
'''
   In  Class constructor __init__() method's first argument,
   Conventionallty "self" key makes the first argument in a class’s method function special.
'''

# %%
#Solution 5
'''
   init method works as a constructor in python object oriented. 
   This method is called when an object is created from a class and it allows the class to initialize the attributes of the class.
'''

# %%
#Solution 6
'''
   We can create class instance by calling the class by its name and pass the arguments to the class which its init method accepts.
   
   e.g : 
       
        classinstance = vehicle(vehicletype,numberofseat)
            
        In above example, vehicle is class name & 'vehicletype' & 'numberofseat' is the 2 argument passing to the __ini__ method.
'''

# %%
#Solution 7
'''
   "class" keyword is used to created a class in python.
   
   e.g : 
       
        class vehicle:
            pass
            
        In above example, vehicle is class name & 'class' keyword helps to create class vehicle.
'''

# %%
#Solution 8
'''
   Superclass class is given as a arugment to the child class as below : 
   
   e.g : 
       
        class car(vehicle):
            pass
            
        In above example, vehicle is superclass & car is representing as child class.
'''
