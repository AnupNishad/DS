# %%
#Solution 1
'''
    The boolean value can be of two types only i.e. either True or False
    a = False
    b = True
'''

# %%
#Solution 2
'''
    Following are the 3 types of boolean operators
    
    1. AND - The Boolean AND operator returns False if any one of the inputs is False else returns True
    2. OR - The Boolean OR operator returns True if any one of the inputs is True else returns False
    3. NOT - The Boolean NOT operator only require one argument and returns the negatation of the argument i.e. returns the True for False and False for True
'''

# %%
#Solution 3
'''
    Truth Table - AND Operator
    --------------------------
                                                
    Boolean Value 1       | Boolean Value 1         | Result
    ---------------------------------------------------------
    TRUE                  | TRUE                    | TRUE
    ---------------------------------------------------------
    TRUE                  | FALSE                   | FALSE
   ----------------------------------------------------------
    FALSE                 | TRUE                    | FALSE
    ---------------------------------------------------------
    FALSE                 | FALSE                   | FALSE

    
    Truth Table - OR Operator
    --------------------------
    
    Boolean Value 1       | Boolean Value 1         | Result
    ---------------------------------------------------------
    TRUE                  | TRUE                    | TRUE
    ---------------------------------------------------------
    TRUE                  | FALSE                   | TRUE
   ----------------------------------------------------------
    FALSE                 | TRUE                    | TRUE
    ---------------------------------------------------------
    FALSE                 | FALSE                   | FALSE
    
    
    Truth Table - NOT Operator
    --------------------------
    
    Boolean Value         | Result
    -------------------------------
    TRUE                  | FALSE 
    -------------------------------
    FALSE                 | TRUE 
    
'''

# %%
#Solution 4
'''
    Values of the following expressions :
    
    1. (5 > 4) and (3 == 5)                  - False
    2. not (5 > 4)                           - False
    3. (5 > 4) or (3 == 5)                   - True
    4. not ((5 > 4) or (3 == 5))             - False
    5. (True and True) and (True == False)   - False
    6. (not False) or (not True)             - True
    
'''

# %%
#Solution 5
'''
    Following are the six comparison operators :
    
    1. Less than ( < ) - The Less Than operator (<) compares two values and returns True if the value on the left is less than the value on the right. Otherwise, it returns False.
    
    2. Less than or equal to (<=) - The less than or equal to operator compares two values and returns True if the left value is less than or equal to the right value. Otherwise, it returns False.
    
    3. Greater than (>) - The greater than operator (>) compares two values and returns True if the left value is greater than the right value. Otherwise, it returns False.
    
    4. Greater than or equal to (>=) - The greater than or equal to operator (>=) compares two values and returns True if the left value is greater than or equal to the right value. Otherwise, it returns False.
    
    5. Equal to ( == ) - The equal to operator (==) compares two values and returns True if the left value is equal to the right value. Otherwise, it returns False.
    
    6. Not equal to ( != ) - The not equal to operator (!=) compares two values and returns True if the left value isn’t equal to the right value. Otherwise, it returns False.
    
'''

# %%
#Solution 6
'''
    Equal Operator(==) - We use 2 Equal symbol/operator.This operator compares two values.
    
    Assignment Operator(=) - We use 1 Equal symbol/operator.This operator assign value to the variable.
    
    e. g 
    
        try:
            a = int(input("Enter Number : "))
            b = 10
            if (a == 0) :
                    b = b+10
        except Exception as e:
                print(e)
        print(b)
        
        In above example , Programme is asking user to enter a number if entered number is equal to 0 (Equal check) then it will increment variable b's values by 10(Assignment).

'''

# %%
#Solution 7
'''
spam = 0
-------------------
if spam == 10:    |
    print('eggs') | Block 1
-------------------
if spam > 5:      |
    print('bacon')| Block 2
-------------------
else:             |
    print('ham')  |
    print('spam') |
    print('spam') | Block 3
-------------------

--OR--

spam = 0
-------------------
if spam == 10:    |
    print('eggs') | Block 1
-------------------
if spam > 5:      |
    print('bacon')| Block 2
-------------------
else:             |
    print('ham')  | Block 3
-------------------
print('spam')
print('spam')

'''

# %%
#Solution 8
try:
    spam = int(input("Enter Number : "))
    if spam == 1:
        print('Hello')
    elif spam == 2:
        print('Howdy')
    else:
        print('Greetings!')
except Exception as e:
    print('Greetings!')

# %%
#Solution 9
'''
    We can interrupt endless loop by pressing CTRL+C & interrupt the kernel by pressing I twice(I,I)
    Also we can restart the kernel by pressing Zero(0) twice (0,0)
'''

# %%
#Solution 10
'''
    Following are the diff. between Break & Continue : 
    
    Break Statement : 
                    1. This statement terminates the smallest enclosing loop.
                    2. The Break statement is used to exit from the loop constructs.
                    3. It can also used in Switch Statement.
                    4. Syntax: - break
    
    Continue Statement : 
                    1. This statement skips the rest of the loop statement and starts the next iteration of the loop to take place.
                    2. The Continue statement is used to exit from the current iteration.
                    3. It can not used in Switch Statement.
                    4. Syntax: - continue    
'''

# %%
#Solution 11
'''
    There is no diff. between range(10), range(0, 10), and range(0, 10, 1) in for loop in programming , but theoratically some minor diff. is as below : 
    
    1. range(10) - Here range function will provide output as 0-9 except 10 (Start with 0 go till 10 except 10)
    2. range(0, 10) - Here range function will provide output as 0-9 except 10 (Start with 0 go till 10 except 10)
    3. range(0, 10, 1) - Here range function will provide output as 0-9 except 10, but take jump of 1 (Start with 0 go till 10 except 10 by jump of 1)
'''

# %%
#Solution 12

for i in range(1,11):
    print(i)
    
i = 1
while i <= 10 : 
    print(i)
    i = i+1

# %%
#Solution 13
'''
    If we have import spam module as below : 
    import spam
    
    Then we can call bacon function from spam module as below : 
    spam.bacon()
'''
