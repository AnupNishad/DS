# %%
#Solution 1

'''
    1. PdfFileReader()  - This needs to be opened in read-binary mode by passing 'rb' as the second argument to open(). 
    2. PdfFileWriter()  - This needs to be opened in write-binary mode with 'wb'.
    
E.g.-->1 :
    
         P1 = open("jupyterlab-slides.pdf", "rb")
         PFR = PyPDF2.PdfFileReader(P1)
         PDFObj = PFR.getPage(0)
         print(PDFObj.extractText())
         PDFObj.close()
         
         Output : 
         ----------------------------------------
         
         # !JupyterLab:
        The Evolution of the Jupyter 
        NotebookThe JupyterLab Team
        Chris Colbert, Jupyter
        Steven Silvester, Quansight
        Afshin Darian, 
        Jupyter
        Ian Rose, Berkeley
        Jason Grout, Bloomberg
        Brian Granger, Cal Poly
        Jessica Forde, Jupyter
        Grant Nestor, Cal Poly
        Cameron Oelsen, Cal Poly
        Fernando Perez, LBNL/Berkeley 
        Cal Poly Interns
        The Larger Jupyter Team
        @jupyterlab on GitHub
        @ProjectJupyter on Twitter
        
E.g.-->2 :
    
        from PyPDF2 import PdfFileWriter, PdfFileReader

        output = PdfFileWriter()
        input1 = PdfFileReader(open("jupyterlab-slides.pdf", "rb"))

        print("jupyterlab-slides.pdf has %d pages." % input1.getNumPages())

        output.addPage(input1.getPage(0))

        output.addPage(input1.getPage(1).rotateClockwise(90))


        output.addPage(input1.getPage(2).rotateCounterClockwise(90))


        page5 = input1.getPage(4)
        page5.mediaBox.upperRight = (
            page5.mediaBox.getUpperRight_x() / 2,
            page5.mediaBox.getUpperRight_y() / 2
        )
        output.addPage(page5)


        outputStream = open("test.pdf", "wb")
        output.write(outputStream)

        outputStream.close()
         
         Output : 
         ----------------------------------------
         jupyterlab-slides.pdf has 22 pages.
         
         test.pdf will have 4 pages out of 22 pages of jupyterlab-slides.pdf as we are writing only 4 pages.
         

'''

# %%
#Solution 2

'''
    PdfFileReader object provides a method called getPage(page_no) to get a page object.
    
    E.g. : 
         from PyPDF2 import PdfFileReader
         pdf_reader = PdfFileReader("/home/jovyan/demo/data/jupyterlab-slides.pdf","rb")
         print(pdf_reader.getPage(5))
         
         Output : 
         -------------------------
         {'/Type': '/Page', '/Parent': IndirectObject(3, 0), '/Resources': IndirectObject(62, 0), '/Contents': IndirectObject(60, 0), '/MediaBox': [0, 0, 1920, 1080], '/Annots': IndirectObject(68, 0)}
    
'''

# %%
#Solution 3

'''
    getNumPages() method of PdfFileReader 'numPages' variable stores the number of pages in the PDF document.
    
    E.g : 
        from PyPDF2 import PdfFileReader
        pdf_reader = PdfFileReader("/home/jovyan/demo/data/jupyterlab-slides.pdf","rb")
        print(pdf_reader.getNumPages())
        
        Output : 
        ----------------------------
        22
'''

# %%
#Solution 4

'''
    We can use PdfFileReader object’s PDF pdfobject.decrypt("swordfish") method.
    
    E.g : 
        from PyPDF2 import PdfFileReader
        pdf_reader = PdfFileReader("/home/jovyan/demo/data/jupyterlab-slides.pdf","rb")
        if pdf_reader.isEncrypted:
            pdf_reader.decrypt("swordfish")
        for page in pdf_reader.pages:
            print(page.extractText())
        
        We can check if encrypted the decrypt it.
        
        Output : 
        ----------------------------
        # !JupyterLab:
        The Evolution of the Jupyter 
        NotebookThe JupyterLab Team
        Chris Colbert, Jupyter
        Steven Silvester, Quansight
        Afshin Darian, 
        Jupyter
        Ian Rose, Berkeley
        Jason Grout, Bloomberg
        Brian Granger, Cal Poly
        Jessica Forde, Jupyter
        Grant Nestor, Cal Poly
        Cameron Oelsen, Cal Poly
        Fernando Perez, LBNL/Berkeley 
        Cal Poly Interns
        The Larger Jupyter Team
        @jupyterlab on GitHub
        @ProjectJupyter on Twitter

        The Jupyter Notebook

        Jupyter
        Notebook¥Interactive
        , browser-based computing environment
        ¥Exploratory
         data science, ML, visualization, analysis, stats
        ¥Reproducible
         document format:
        ¥Code¥Narrative text (markdown)
        ¥Equations (LaTeX)
        ¥Images, visualizations
        ¥Over 50 programming languages
        ¥Everything open-source (BSD license)
        Interactive, Exploratory
        , Reproducible

        Jupyter
        NotebookA Jupyter Notebook document with a visualization of measles data.

        Project Jupyter: Where are we today?

        Millions of 
        Users
        https://github.com/jupyter/design/blob/master/surveys/2015-notebook-ux/analysis/report_dashboard.ipynb

        Millions of 
        Notebooks
        https://github.com/trending/jupyter-notebook

        Enabling
        Reproducible
        Science
        https://losc.ligo.org/about/
        Live 
        Code onBinder
        https://beta.mybinder.org/v2/gh/minrk/ligo-binder/master?filepath=index.ipynb
        https://losc.ligo.org/tutorials/
        LIGO Binder

        Enabling
        Open DataJournalism

        Authoring
        Interactive 
        Books
        https://www.oreilly.com/ideas/jupyter-at-oreilly
        OÕReilly Atlas authoring platform incorporating live code

        Building Blocks for Interactive Computing

        Classic Jupyter: More Than Just Notebooks

        KernelsOutput
        Text Editor
        Terminal
        File BrowserNotebooks
        Building
        Blocks

        Introducing JupyterLab

        JupyterLab: Integrated Experience

        JupyterLab
        ¥Work with the building blocks in a flexible and integrated manner
        ¥Modern JavaScript development: npm-based packaging, 
        Typescript, phosphor.js
        ¥Clean model/view separation
        ¥Well separated public/private APIs
        ¥Fully extensible by third parties
        ¥High performance
        ¥Design!
        Building Blocks

        January 
        2018¥https://github.com/jupyterlab
        ¥~2.5 years worth of development
        ¥~100 contributors, ~60 components
        ¥~1,800 releases (npm+python)
        ¥Over 11,000 commits, ~classic notebook
        ¥Currently Beta
        JupyterLab Today

        Roadmap
        ¥Beta releases, January 2018
        ¥For all users
        ¥For adventurous extension developers
        ¥1.0 this year
        ¥For all users, extension developers
        ¥Eventually:
        ¥Classic notebook will be retired
        JupyterLab Beta: Use It Today
        conda install -c conda-forge jupyterlab
        or pip install jupyterlab

        JupyterCon
        JupyterCon, Aug 21-25, New York

        Live Demos!

        Thank You!
        JupyterCon, Aug 21-25, New York
        conda install -c conda-forge jupyterlab
        or pip install jupyterlab
'''

# %%
#Solution 5

'''
    1. rotateClockwise()        - For Clockwise rotation.
    2. rotateCounterClockwise() - For Counter Clockwise rotation. 
    The degrees to rotate is passed as an integer argument.
    
    E.g : 
    
        from PyPDF2 import PdfFileWriter, PdfFileReader

        output = PdfFileWriter()
        input1 = PdfFileReader(open("jupyterlab-slides.pdf", "rb"))

        print("jupyterlab-slides.pdf has %d pages." % input1.getNumPages())

        output.addPage(input1.getPage(0))

        output.addPage(input1.getPage(1).rotateClockwise(90))


        output.addPage(input1.getPage(2).rotateCounterClockwise(90))
        
        Above program having uses of rotateClockwise & rotateCounterClockwise method.
'''

# %%
#Solution 6

'''
    1. Paragraph - A document contains multiple paragraphs. 
                   A paragraph begins on a new line and contains multiple runs.
                   
    2. Run       - Runs are contiguous groups of characters within a paragraph.
'''

# %%
#Solution 7

'''
    We can use "doc.paragraphs" to obtain a list of Paragraph objects 
    for a Document object that’s stored in a variable named doc.
    
'''

# %%
#Solution 8

'''
    Run object has bold, underline, italic, strike, and outline variables.
    
'''

# %%
#Solution 9

'''
    1. True - This always makes the Run object bolded.
    2. False - This makes it always not bolded, no matter what the style’s bold setting is. 
    3. None  - This will make the Run object just use the style’s bold setting.
    
'''

# %%
#Solution 10

'''
    We can create a Document object for a new Word document by calling the docx.Document() function.
    
    e.g : 
         doc = docx.Document(file_path)
    
'''

# %%
#Solution 11

import docx
doc = docx.Document()
doc.add_paragraph('Hello, there!')
doc.save('hello.docx')

# %%
#Solution 12

'''
    We can use "add_heading()" method to represent the levels of headings available in Word documents.
    There are a total of 5 levels statring from 0 to 4.
'''
