# %%
#Solution 1
'''
    [] - It means empty list, which contains no element.
'''

# %%
#Solution 2
''' 
    spam = [2, 4, 6, 8, 10]
    We can assign third value as 'hello' which would replace 6 by 'hello' as value 6 is present at third place as below : 
    spam[2] = "hello"
'''

# %%
#Solution 3
''' 
    spam = ['a', 'b', 'c', 'd']
    
    The value of spam[int(int('3' * 2) / 11)] = 'd'
'''

# %%
#Solution 4
''' 
    spam = ['a', 'b', 'c', 'd']
    
    The value of spam[-1] = 'd'
'''

# %%
#Solution 5
''' 
    spam = ['a', 'b', 'c', 'd']

    The value of spam[:2] = ['a', 'b']
'''

# %%
#Solution 6
''' 
    In question bacon = [3.14, 'cat,' 11, 'cat,' True] this list creation will give error as comma in cat string itself not outside.
    
    I have removed the comma from cat string & put it on outside as below: 
    bacon = [3.14, 'cat', 11, 'cat', True]

    bacon.index('cat') = 1 (As index function provide the index for first element if duplicated)
'''

# %%
#Solution 7
''' 
    bacon = [3.14, 'cat', 11, 'cat', True]

    bacon.append(99) = [3.14, 'cat', 11, 'cat', True, 99] (As append function adds element at the end to the list)
'''

# %%
#Solution 8
''' 
    bacon = [3.14, 'cat', 11, 'cat', True]

    bacon.remove('cat') = [3.14, 11, 'cat', True] (As remove function removes first occurrence of value from the list)
'''

# %%
#Solution 9
''' 
    1. Operator for list concatenation is '+'
    2. Operator for list replication is '*'
'''

# %%
#Solution 10
''' 
    1. append() - It will add the element at the end of the list. 
    2. insert() - it will insert the element at the specified index.
'''

# %%
#Solution 11
''' 
    1. remove() - It helps to remove the very first given element matching from the list. e.g bacon.remove('cat')
    2. del - it is used to delete the value by slice. e.g del bacon[1] - 1 respresent index of element to be delete.
'''

# %%
#Solution 12
''' 
    If we have string as 'Hello' & list as bacon (above one)
    We can pass both of them into len() & get the length of those. e.g len('Hello') & len(bacon)
    If we use in loop both have indexes & slices.
    We can concatenated or replicate y using + & * operator.
'''

# %%
#Solution 13
''' 
    1. List - 
            1. Lists are mutable e.g We can add,remove & changed added values.
            2. Lists use the square brackets [].
            
    2. Tuple - 
            1. Tuples are immutable e.g It cannot be changed.
            2. Tuples use the parentheses ().
'''

# %%
#Solution 14
''' 
    We can write t = (42,) to create tuple with only integer 42.
    If we write t = (42) it will assign 42 to variable t & will not create tuple.
'''

# %%
#Solution 15
''' 
    Let's assume we have list l=[1,2,3,4,5] & tuple t=(5,4,3,2,1)
    
    Get a list value's tuple form = tuple(l) - Use tuple() function to convert list to tuple
    Get a tuple value's list form = list(t) - Use list() function to convert tuple to list
'''

# %%
#Solution 16
''' 
    They contain references to list values.
'''

# %%
#Solution 17
''' 
    copy.copy() - will do a shallow copy of a list.
    copy.deepcopy() - Will do a deep copy of a list.
'''
