# %%
#Solution 1
'''
    Escape characters represent characters in string values that would otherwise be difficult or impossible to type into code
'''

# %%
#Solution 2
'''
    1. \n is a newline.
    2. \t is a tab.
'''

# %%
#Solution 3
'''
     The \\ escape character will represent a backslash character in a string.
'''

# %%
#Solution 4
'''
    The single quote character in the word 'Howl's' is not escaped a problem because we’ve used double quotes to mark the beginning and end of the string.
'''

# %%
#Solution 5
'''
    Multiline strings allow you to use newlines in strings without the \n escape character.
'''

# %%
#Solution 6
'''
    1. 'Hello, world!'[1] = 'e'
    2. 'Hello, world!'[0:5] = 'Hello'
    3. 'Hello, world!'[:5] = 'Hello'
    4. 'Hello, world!'[3:] = 'lo, world!'
'''

# %%
#Solution 7
'''
    1. 'Hello'.upper() = 'HELLO'
    2. 'Hello'.upper().isupper() = True
    3. 'Hello'.upper().lower() = 'hello'
'''

# %%
#Solution 8
'''
    1. 'Remember, remember, the fifth of July.'.split() = ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']
    
    2. '-'.join('There can only one.'.split()) = 'There-can-only-one.'
'''

# %%
#Solution 9
'''
    1. right-justifying - rjust()
    
    2. left-justifying  - ljust()
    
    3. centering - center()
'''

# %%
#Solution 10
'''
    1. lstrip() - Removes whitespace characters from the start.
    
    2. rstrip()  - Removes whitespace characters from the end.
'''
