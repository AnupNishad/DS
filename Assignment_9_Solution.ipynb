# %%
#Solution 1
'''
    Relative paths are relative to the current working directory.
'''

# %%
#Solution 2
'''
    Absolute paths start with the root folder, such as / or C:\.
'''

# %%
#Solution 3
'''
    1. os.getcwd() - This function returns the current working directory.
    2. os.chdir()  - This function changes the current working directory.
'''

# %%
#Solution 4
'''
    1. (.)   - The . folder is the current folder.
    2. (..)  - The .. is the parent folder.
'''

# %%
#Solution 5
'''
    In C:\bacon\eggs\spam.txt,
            
            1. C:\bacon\eggs is the dir name.
            2. spam.txt is the base name.
'''

# %%
#Solution 6
'''
    Below are the 3 "mode" argument that can be passed to open() function : 
        
        1. 'r' - open for reading (default)
        2. 'w' - open for writing, truncating the file first
        3. 'x' - create a new file and open it for writing
'''

# %%
#Solution 7
'''
   if an existing file is opened in write mode that file would be overwritten.
'''

# %%
#Solution 8
'''
   1. read()      -  This method returns the file’s entire contents as a single string value.
   2. readlines() -  This method read file's contents line by line & returns the output.
'''

# %%
#Solution 9
'''
   A shelf value resembles a dictionary value.it has keys and values, along with keys() and values() methods.
'''
